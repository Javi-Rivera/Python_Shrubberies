# %%
import random
# Import Random module for generation of random number for computer choice

def name_to_number(name):
    # Auxiliar function that converts name into a number
    name = str(name) # we convert the given option into a string
    if name == 'rock':
        name_number = 0
        return(name_number)
    elif name == 'Spock':
        name_number = 1
        return(name_number)
    elif name == 'paper':
        name_number = 2
        return(name_number)
    elif name == 'lizard':
        name_number = 3
        return(name_number)
    elif name == 'scissors':
        name_number = 4
        return(name_number)
    else:
        return('Error: Insert a valid option') # message showed if player inserts a different option
    
# Test calls the name_to_number()
###
#print(name_to_number('rock'))
#print(name_to_number('Spock'))
#print(name_to_number('paper'))
#print(name_to_number('lizard'))
#print(name_to_number('scissors'))
#print(name_to_number('oso'))

def number_to_name(number):
    # Second Auxiliar function taht converts a number into a name
    if number == 0:
        number_name = 'rock'
        return(number_name)
    elif number == 1:
        number_name = 'Spock'
        return(number_name)
    elif number == 2:
        number_name = 'paper'
        return(number_name)
    elif number == 3:
        number_name = 'lizard'
        return(number_name)
    elif number == 4:
        number_name = 'scissors'
        return(number_name)
    else:
        return('Error: Insert a valid number') # message showed if player inserts a different number option
    
# Test calls number_to_name()
###
#print(number_to_name(0))
#print(number_to_name(1))
#print(number_to_name(2))
#print(number_to_name(3))
#print(number_to_name(4))
#print(number_to_name(5))'''

def rpsls(player_choice):
    # we define the first part of the main function
    print('\n')
    #print('''Please enter one number from 0 to 4:
    #        for 0 - rock,
    #            1 - Spock,
    #            2 - paper,
    #            3 - lizard and
    #            4 - scissors''')
    player_choice = name_to_number(player_choice)
    player_choice = number_to_name(player_choice)
    print('You choose: ', player_choice)
    computer_number = random.randrange(1, 5)
    computer_choice = number_to_name(computer_number)
    print('Computer choice: ', computer_choice)
    win = False    
    if player_choice == 'rock' and (computer_choice == 'scissors' or computer_choice == 'lizard'):
        return('''You Win!!!! Congratulations!!!''')
    elif player_choice == 'scissors' and (computer_choice == 'lizard' or computer_choice == 'paper'):
        return('''You Win!!!! Congratulations!!!''')
    elif player_choice == 'lizard' and (computer_choice == 'paper' or computer_choice == 'Spock'):
        return('''You Win!!!! Congratulations!!!''')
    elif player_choice == 'paper' and (computer_choice == 'Spock' or computer_choice == 'rock'):
        return('''You Win!!!! Congratulations!!!''')
    elif player_choice == 'Spock' and (computer_choice == 'rock' or computer_choice == 'scissors'):
        return('''You Win!!!! Congratulations!!!''')
    elif computer_choice == 'rock' and (player_choice == 'scissors' or player_choice == 'lizard'):
        return('''You Lose!!!!, Better luck next time''')
    elif computer_choice == 'scissors' and (player_choice == 'lizard' or player_choice == 'paper'):
        return('''You Lose!!!!, Better luck next time''')
    elif computer_choice == 'lizard' and (player_choice == 'paper' or player_choice == 'Spock'):
        return('''You Lose!!!!, Better luck next time''')
    elif computer_choice == 'paper' and (player_choice == 'Spock' or player_choice == 'rock'):
        return('''You Lose!!!!, Better luck next time''')
    elif computer_choice == 'Spock' and (player_choice == 'rock' or player_choice == 'scissors'):
        return('''You Lose!!!!, Better luck next time''')
    else:
        return('Tie! Choose Again')
### Test
#print(rpsls(0))
#print(rpsls(1))
#print(rpsls(2))
#print(rpsls(3))
#print(rpsls(4))
###
print('''Please choose one:
                                      rock
                                      paper
                                      scissors
                                      lizzard
                                      Spock''')
player_choice = input('Enter Choice: ')
rpsls(player_choice)
# Out:
# Please choose one:
#                                       rock
#                                       paper
#                                       scissors
#                                       lizzard
#                                       Spock
# Enter Choice: paper
#
#
# You choose:  paper
# Computer choice:  Spock
# 'You Win!!!! Congratulations!!!'
